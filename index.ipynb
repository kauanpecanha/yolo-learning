# %%
# !python --version
# Out:
# Python 3.11.7

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
cd yolov10
# Out:
# C:\Users\kauan\code\python\yolo-learning-v2\yolov10

# %%
pip install .

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10n.pt
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10s.pt
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10m.pt
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10b.pt
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10x.pt
# Downloaded C:\Users\kauan\code\python\yolo-learning-v2\yolov10\weights\yolov10l.pt

# %%
# !yolo task=detect mode=train epochs=30 batch=16 plots=True model=weights/yolov10n.pt data=config.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.27 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.0+cpu CPU (13th Gen Intel Core(TM) i5-13450HX)
# ...

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train7/weights/best.pt source=tom.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.0+cpu CPU (13th Gen Intel Core(TM) i5-13450HX)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\kauan\anaconda3\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\kauan\anaconda3\Lib\site-packages\ultralytics\cfg\__init__.py", line 587, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\kauan\anaconda3\Lib\site-packages\ultralytics\engine\model.py", line 443, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
